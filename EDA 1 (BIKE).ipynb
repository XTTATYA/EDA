# %%
                                                                           #Assignment

# %%
                                                                           #EDA 1 BIKE

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("BIKE.csv")

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.describe(include='all')
# Out:
#                     name  selling_price         year seller_type      owner  \
# count               1061    1061.000000  1061.000000        1061       1061
# unique               279            NaN          NaN           2          4
# top     Bajaj Pulsar 150            NaN          NaN  Individual  1st owner
# freq                  41            NaN          NaN        1055        924
# mean                 NaN   59638.151744  2013.867107         NaN        NaN
# std                  NaN   56304.291973     4.301191         NaN        NaN
# min                  NaN    5000.000000  1988.000000         NaN        NaN
# 25%                  NaN   28000.000000  2011.000000         NaN        NaN
# 50%                  NaN   45000.000000  2015.000000         NaN        NaN
# 75%                  NaN   70000.000000  2017.000000         NaN        NaN
# max                  NaN  760000.000000  2020.000000         NaN        NaN
#
#             km_driven  ex_showroom_price
# ...

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
#here all the columns are correct except the last cloum which has null values present in it
df['ex_showroom_price']
# Out:
# 0            NaN
# 1            NaN
# 2       148114.0
# 3        89643.0
# 4            NaN
#           ...
# 1056     52000.0
# 1057     51000.0
# 1058     57000.0
# 1059     58000.0
# 1060     75000.0
# Name: ex_showroom_price, Length: 1061, dtype: float64

# %%
df.duplicated().sum() #there are 6 duplicate values
# Out:
# np.int64(6)

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
#now lets check the data
df.head(5)
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df['name'].unique()
# Out:
# array(['Royal Enfield Classic 350', 'Honda Dio',
#        'Royal Enfield Classic Gunmetal Grey',
#        'Yamaha Fazer FI V 2.0 [2016-2018]', 'Yamaha SZ [2013-2014]',
#        'Honda CB Twister', 'Honda CB Hornet 160R',
#        'Royal Enfield Bullet 350 [2007-2011]', 'Hero Honda CBZ extreme',
#        'Bajaj Discover 125', 'Yamaha FZ16', 'Honda Navi',
#        'Bajaj Avenger Street 220', 'Yamaha YZF R3', 'Jawa 42',
#        'Suzuki Access 125 [2007-2016]', 'Hero Honda Glamour',
#        'Yamaha YZF R15 S', 'Yamaha FZ25', 'Hero Passion Pro 110',
#        'Honda Navi [2016-2017]', 'Honda Activa i', 'Jawa Standard',
#        'Royal Enfield Thunderbird 350', 'Honda Dream Yuga',
#        'TVS Apache RTR 160 4V', 'Yamaha Fazer [2009-2016]',
#        'Hero Honda Splendor NXG', 'Hero Glamour 125',
#        'Yamaha FZ S [2012-2016]', 'Hero Xtreme Sports', 'Honda X-Blade',
#        'Honda CB Shine SP', 'Honda Activa 5G', 'Honda CBR-250R',
# ...

# %%
def brackets(df,column):
  df[column] = df[column].str.replace(r'\[.*?\]', '', regex=True).str.strip()
  return df[column]
df['name']=brackets(df,'name')

# %%
#all the brackets are removed
df['name'].unique()
# Out:
# array(['Royal Enfield Classic 350', 'Honda Dio',
#        'Royal Enfield Classic Gunmetal Grey', 'Yamaha Fazer FI V 2.0',
#        'Yamaha SZ', 'Honda CB Twister', 'Honda CB Hornet 160R',
#        'Royal Enfield Bullet 350', 'Hero Honda CBZ extreme',
#        'Bajaj Discover 125', 'Yamaha FZ16', 'Honda Navi',
#        'Bajaj Avenger Street 220', 'Yamaha YZF R3', 'Jawa 42',
#        'Suzuki Access 125', 'Hero Honda Glamour', 'Yamaha YZF R15 S',
#        'Yamaha FZ25', 'Hero Passion Pro 110', 'Honda Activa i',
#        'Jawa Standard', 'Royal Enfield Thunderbird 350',
#        'Honda Dream Yuga', 'TVS Apache RTR 160 4V', 'Yamaha Fazer',
#        'Hero Honda Splendor NXG', 'Hero Glamour 125', 'Yamaha FZ S',
#        'Hero Xtreme Sports', 'Honda X-Blade', 'Honda CB Shine SP',
#        'Honda Activa 5G', 'Honda CBR-250R', 'Hero Honda Passion PRO',
#        'Bajaj Dominar 400', 'Hero Glamour FI', 'KTM 390 Duke',
#        'Hero Passion XPro', 'Yamaha FZ S V 2.0', 'Hero Achiever 150',
# ...

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3                   Yamaha Fazer FI V 2.0          65000  2015  Individual
# 4                               Yamaha SZ          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
df['ex_showroom_price'].isnull().sum() #435 rows have nan value
# Out:
# np.int64(435)

# %%
df['ex_showroom_price'] = df['ex_showroom_price'].fillna(df['ex_showroom_price'].median())

# %%
# all nan values have been removed
df['ex_showroom_price']
# Out:
# 0        72752.5
# 1        72752.5
# 2       148114.0
# 3        89643.0
# 4        72752.5
#           ...
# 1056     52000.0
# 1057     51000.0
# 1058     57000.0
# 1059     58000.0
# 1060     75000.0
# Name: ex_showroom_price, Length: 1061, dtype: float64

# %%
df['ex_showroom_price'].unique()
# Out:
# array([  72752.5,  148114. ,   89643. ,   53857. ,   87719. ,   60122. ,
#          78712. ,   47255. ,   95955. ,  351680. ,   58314. ,  117926. ,
#         132680. ,   44389. ,   53900. ,   56147. ,   84751. ,   61600. ,
#          79432. ,   78350. ,   71049. ,   57557. ,  202310. ,   71150. ,
#          56750. ,   84042. ,   69750. ,   59844. ,   42859. ,   73413. ,
#          49900. ,   59422. ,   57549. ,   51994. ,   80350. ,   54605. ,
#          88161. ,   78513. ,   50098. ,  195500. ,   92074. ,  164004. ,
#          74295. ,   49642. ,   51112. ,   53751. ,   50267. ,   61653. ,
#          70851. ,   53079. ,  133680. ,  181445. ,   65626. ,   58438. ,
#          61118. ,   75936. ,  180525. ,   87543. ,   80435. ,   85011. ,
#        1278000. ,  155740. ,  202127. ,   86744. ,  156304. ,   84246. ,
#          49521. ,   64589. ,   69983. ,   54299. ,   72303. ,   65800. ,
#          58757. ,   47032. ,   79233. ,  118997. ,   52949. ,   64071. ,
# ...

# %%
df['ex_showroom_price']=df['ex_showroom_price'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  1061 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 58.2+ KB

# %%
df['owner'].unique()
# Out:
# array(['1st owner', '2nd owner', '3rd owner', '4th owner'], dtype=object)

# %%
# lets convert this into a int type by encoding this
df['owner']=df['owner'].map({'1st owner':1,'2nd owner':2,'3rd owner':3,'4th owner':4})

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3                   Yamaha Fazer FI V 2.0          65000  2015  Individual
# 4                               Yamaha SZ          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#       owner  km_driven  ex_showroom_price
# ...

# %%
Q1 = df['selling_price'].quantile(0.25)
Q3 = df['selling_price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = df[(df['selling_price'] < lower_bound) | (df['selling_price'] > upper_bound)]
print(outliers)
#there are some outliers present in selling price
# Out:
#                                     name  selling_price  year seller_type  \
# 0              Royal Enfield Classic 350         175000  2019  Individual
# 2    Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 7               Royal Enfield Bullet 350         180000  2008  Individual
# 13                         Yamaha YZF R3         365000  2019  Individual
# 14                               Jawa 42         185000  2020  Individual
# ..                                   ...            ...   ...         ...
# 962                            KTM RC200         165000  2019  Individual
# 963                    Bajaj Dominar 400         145000  2019  Individual
# 964            Royal Enfield Classic 350         135000  2019  Individual
# 965                            KTM RC390         135000  2017  Individual
# 966                       Hyosung GT250R         135000  2016  Individual
#
#      owner  km_driven  ex_showroom_price
# ...

# %%
sns.boxplot(df['selling_price'])
plt.title("Distribution of Bike Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

median_price = df['selling_price'].median()

# Step 3: Replace outliers with median
df['selling_price'] = df['selling_price'].apply(lambda x: median_price if x < lower_bound or x > upper_bound else x)

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350        45000.0  2019  Individual
# 1                               Honda Dio        45000.0  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey        45000.0  2018  Individual
# 3                   Yamaha Fazer FI V 2.0        65000.0  2015  Individual
# 4                               Yamaha SZ        20000.0  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g        17000.0  2010  Individual
# 1057                     Honda CB twister        16000.0  2012  Individual
# 1058                   Bajaj Discover 125        15000.0  2013  Individual
# 1059                       Honda CB Shine        12000.0  2009  Individual
# 1060                     Bajaj Pulsar 150        10000.0  2008  Individual
#
#       owner  km_driven  ex_showroom_price
# ...

# %%
#Now the data has been prepared and cleaned for vizualization and analysis

# %%
#Q1 What is the range of selling prices in the datasetD?
"""Ans"""
df.describe()
# Out:
#        selling_price         year        owner      km_driven  \
# count    1061.000000  1061.000000  1061.000000    1061.000000
# mean    47480.753063  2013.867107     1.145146   34359.833176
# std     26721.333527     4.301191     0.402407   51623.152702
# min      5000.000000  1988.000000     1.000000     350.000000
# 25%     28000.000000  2011.000000     1.000000   13500.000000
# 50%     45000.000000  2015.000000     1.000000   25000.000000
# 75%     60000.000000  2017.000000     1.000000   43000.000000
# max    130000.000000  2020.000000     4.000000  880000.000000
#
#        ex_showroom_price
# count       1.061000e+03
# mean        8.172410e+04
# std         5.997582e+04
# min         3.049000e+04
# 25%         6.458900e+04
# 50%         7.275200e+04
# 75%         7.851300e+04
# max         1.278000e+06

# %%
sns.histplot(df['selling_price'],bins=30,kde=True)
plt.title("Distribution of Bike Prices")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()
#insights:- most people buy bike whose selling price are below 80000

# %%
#Q2) What is the median selling price for bikes in the dataset?
"""Ans"""
median_price = df['selling_price'].median()
print(f"The Median price of selling price is {median_price}")
# Out:
# The Median price of selling price is 45000.0

# %%
#Q3)What is the most common seller type?
"""Ans"""
df.head(2)
# Out:
#                         name  selling_price  year seller_type  owner  \
# 0  Royal Enfield Classic 350        45000.0  2019  Individual      1
# 1                  Honda Dio        45000.0  2017  Individual      1
#
#    km_driven  ex_showroom_price
# 0        350              72752
# 1       5650              72752

# %%
df['seller_type'].value_counts().head(1) #the most common seller type is individual
plt.figure(figsize=(10,6))
sns.countplot(x='seller_type',data=df,palette='Set2')
plt.title("Seller Types")
plt.xlabel("Seller Type")
plt.ylabel("Count")
plt.show()
#insights is that most people consider seller type to be an individual

# %%
#Q4)How many bikes have driven more than 50,000 kilometers?
"""Ans"""
Bike_names = df[df['km_driven']>50000]['name'].value_counts()
Bike_names
# Out:
# name
# Bajaj Pulsar 150            18
# Hero Honda Splendor Plus     9
# Bajaj Discover 125           7
# Hero Honda Passion Plus      7
# Honda Activa                 7
#                             ..
# TVS Victor                   1
# Honda Karizma                1
# Hero Honda Passion Pro       1
# Activa 3g                    1
# Honda CB Shine               1
# Name: count, Length: 76, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df[df['km_driven']>50000]['name'])
plt.xticks(rotation=90)
plt.show()
#insight states that bajaj pulsar 150 has most number of bike which has driven more than 50000 km

# %%
above_50k = df[df['km_driven'] > 50000].shape[0]
below_50k = df[df['km_driven'] <= 50000].shape[0]

sns.barplot(x=['> 50,000 km', '≤ 50,000 km'], y=[above_50k, below_50k])
plt.title("Bike Count Based on Kilometers Driven")
plt.ylabel("Number of Bikes")
plt.show()
#insight states that more than 800 bikes have travelled more than 50000

# %%
#Q5) What is the average km_driven value for each ownership type?
"""Ans"""
red=df.groupby('owner')['km_driven'].mean()
sns.barplot(x='owner',y='km_driven',estimator='mean',data=df,ci=None,palette='Set3')
plt.title("Average KM driven based on ownership")
plt.xlabel('Owner Type')
plt.ylabel('KM')
plt.show()
#insights states that owner type 3 has more driven avarage km

# %%
#Q6)What proportion of bikes are from the year 2015 or older?
"""Ans"""

a=df[df['year']<=2015].value_counts().shape[0]
b=df[df['year']>2015].value_counts().shape[0]
print(a,b)
sns.barplot(x=['Below Or Equal To 2015','Above 2015'],y=[a,b],palette='Set3')
plt.title("Proportion of bikers above or below 2015")
plt.ylabel("Bike Count")
# Out:
# 597 457
# Text(0, 0.5, 'Bike Count')

# %%
#Q7)What is the trend of missing values across the dataset?
"""Ans
For this question i had already treated all the missing values during data prepration"""
# Out:
# 'Ans\nFor this question i had already treated all the missing values during data prepration'

# %%
#Q8)What is the highest ex_showroom_price recorded, and for which bike?
"""Ans"""
Bike=df.loc[df['ex_showroom_price'].idxmax(), 'name']
Bike
# Out:
# 'Harley-Davidson Street Bob'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   float64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   int64
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  1061 non-null   int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 58.2+ KB

# %%
#Q9) What is the total number of bikes listed by each seller type?
"""Ans"""
a=df['seller_type'].value_counts()
sns.barplot(x=a.index,y=a.values,palette='Set2')
plt.title('Bikes Sold On Dealer Types')
# Out:
# Text(0.5, 1.0, 'Bikes Sold On Dealer Types')

# %%
#Q10)What is the relationship between selling_price and km_driven for first-owner bikes?
"""Ans"""
sns.scatterplot(data=df[df['owner']==1], x=df['km_driven'], y=df['selling_price'],palette='coolwarm')
plt.show()
# insights states that most people prefer bikes with around 200000  selling price and below 200000 km driven

# %%
#Q11) Identify and remove outliers in the km_driven column using the IQR method?
"""Ans"""
sns.boxplot(data=df['km_driven'])

q1=df['km_driven'].quantile(0.25)
q3=df['km_driven'].quantile(0.75)
IQR=q3-q1
lower=q1-1.5*IQR
upper=q3+1.5*IQR
outliers=[km for km in df['km_driven'] if km < lower or km > upper]
outliers


median= df['km_driven'].median()

df.loc[df['km_driven'].isin(outliers), 'km_driven'] = median

# %%
#Q12)Perform a bivariate analysis to visualize the relationship between year and selling_price?
"""Ans"""
plt.figure(figsize=(15,10))
sns.barplot(x='year',y='selling_price',data=df,palette='coolwarm',ci=None)
plt.title("Relationship between year and selling price")
plt.xlabel("Year")
plt.ylabel("Price")
plt.xticks(rotation=90)
plt.show()
#the most coslty bike was sold in 1993 for a price of above 120000

# %%
#Q13) What is the average depreciation in selling price based on the bike's year?
"""Ans"""
#Depreciation = Ex-Showroom Price − Selling Price
df['Depreciation']=df['ex_showroom_price']-df['selling_price']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   float64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   int64
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  1061 non-null   int64
#  7   Depreciation       1061 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 66.4+ KB

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350        45000.0  2019  Individual
# 1                               Honda Dio        45000.0  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey        45000.0  2018  Individual
# 3                   Yamaha Fazer FI V 2.0        65000.0  2015  Individual
# 4                               Yamaha SZ        20000.0  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g        17000.0  2010  Individual
# 1057                     Honda CB twister        16000.0  2012  Individual
# 1058                   Bajaj Discover 125        15000.0  2013  Individual
# 1059                       Honda CB Shine        12000.0  2009  Individual
# 1060                     Bajaj Pulsar 150        10000.0  2008  Individual
#
#       owner  km_driven  ex_showroom_price  Depreciation
# ...

# %%
avg_depreciation_by_year = df.groupby('year')['Depreciation'].mean().reset_index()
plt.figure(figsize=(12,6))
sns.barplot(data=avg_depreciation_by_year, x='year', y='Depreciation', palette='viridis')
plt.title('Average Depreciation in Selling Price by Year')
plt.xlabel('Year')
plt.ylabel('Average Depreciation')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
avg_depreciation_by_year = df.groupby('year')['Depreciation'].mean()
avg_depreciation_by_year
# Out:
# year
# 1988    52752.000000
# 1991    66752.000000
# 1993   -57248.000000
# 1995    27752.000000
# 1997    55252.000000
# 1998    44418.666667
# 1999    57752.000000
# 2000    51918.666667
# 2001    23802.000000
# 2002    52085.333333
# 2003    64752.000000
# 2004    54072.000000
# 2005    54494.857143
# 2006    45054.500000
# 2007    46713.448276
# 2008    43747.107143
# 2009    44543.464286
# 2010    43275.233333
# 2011    47302.377049
# 2012    35616.700000
# 2013    47741.712329
# 2014    35343.626374
# 2015    28801.020000
# 2016    26437.981308
# 2017    24196.338346
# 2018    25331.183206
# 2019    29198.802326
# 2020    55414.666667
# Name: Depreciation, dtype: float64

# %%
#Q14)Which bike names are priced significantly above the average price for their year?
"""Ans"""
a=df[df['selling_price']>=df['selling_price'].mean()]['name']
a
# Out:
# 3          Yamaha Fazer FI V 2.0
# 6           Honda CB Hornet 160R
# 9             Bajaj Discover 125
# 12      Bajaj Avenger Street 220
# 19                   Yamaha FZ25
#                   ...
# 1014                Yamaha Fazer
# 1015             Honda Activa 4G
# 1016                   TVS Sport
# 1017           Yamaha FZ S V 2.0
# 1018            Honda Dream Yuga
# Name: name, Length: 389, dtype: object

# %%
#Q15) Develop a correlation matrix for numeric columns and visualize it using a heatmap?
"""Ans"""
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title('Correlation Matrix of Numeric Features')
plt.show()
